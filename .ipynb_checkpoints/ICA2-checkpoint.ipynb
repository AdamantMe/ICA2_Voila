# %%
import os
import pandas as pd
import numpy as np
import folium

# %%
confirmed_df = pd.read_csv("raw_data_files/confirmed_regions.csv")
deaths_df = pd.read_csv("raw_data_files/deaths_regions.csv")

# %%
confirmed_df.set_index(confirmed_df['Country/Region'],inplace=True)
deaths_df.set_index(deaths_df['Country/Region'],inplace=True)
confirmed_df = confirmed_df.iloc[1: , :]
deaths_df = deaths_df.iloc[1: , :]

#Renaming columns
confirmed_df.rename(columns={'Country/Region': 'Country'},inplace=True)
deaths_df.rename(columns={'Country/Region': 'Country'},inplace=True)

confirmed_df.rename(columns={'Region Name': 'Continent'},inplace=True)
deaths_df.rename(columns={'Region Name': 'Continent'},inplace=True)

confirmed_df.rename(columns={'Sub-region Name': 'Region'},inplace=True)
deaths_df.rename(columns={'Sub-region Name': 'Region'},inplace=True)

# %%
confirmed_df=confirmed_df.drop(columns=['Province/State', 'ISO 3166-1 Alpha 3-Codes', 'Intermediate Region Code', 'Intermediate Region Name'])

countries_confirmed_df=confirmed_df.groupby(['Country']).sum().copy()
countries_deaths_df=deaths_df.groupby(['Country']).sum().copy()

# %%
combined_df=pd.DataFrame()
combined_df['Confirmed']=countries_confirmed_df[countries_confirmed_df.columns[-1]]
combined_df['Deaths']=countries_deaths_df[countries_deaths_df.columns[-1]]

# %%
sorted_combined_df=combined_df.loc[:,["Confirmed","Deaths"]].sort_values("Confirmed",ascending=False)
sorted_combined_df['Country']=sorted_combined_df.index
combined_df.loc[:,["Confirmed","Deaths"]].sort_values("Confirmed",ascending=False).style.background_gradient(cmap='Blues',subset=["Confirmed"]).background_gradient(cmap='Reds',subset=["Deaths"])
# Out:
# <style type="text/css">
# #T_59f5b_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_59f5b_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_59f5b_row1_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_59f5b_row1_col1 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_59f5b_row2_col0 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_59f5b_row2_col1 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_59f5b_row3_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_59f5b_row3_col1 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_59f5b_row4_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_59f5b_row4_col1 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_59f5b_row5_col0, #T_59f5b_row6_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_59f5b_row5_col1 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_59f5b_row6_col1 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_59f5b_row7_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_59f5b_row7_col1, #T_59f5b_row15_col1 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_59f5b_row8_col0 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_59f5b_row8_col1, #T_59f5b_row18_col1 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_59f5b_row9_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_59f5b_row9_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_59f5b_row10_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_59f5b_row10_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_59f5b_row11_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_59f5b_row11_col1, #T_59f5b_row12_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_59f5b_row12_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_59f5b_row13_col0, #T_59f5b_row14_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_59f5b_row13_col1 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_59f5b_row14_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_59f5b_row15_col0 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_59f5b_row16_col0, #T_59f5b_row17_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_59f5b_row16_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_59f5b_row17_col1, #T_59f5b_row25_col1, #T_59f5b_row36_col1, #T_59f5b_row56_col1, #T_59f5b_row78_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_59f5b_row18_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_59f5b_row19_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_59f5b_row19_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_59f5b_row20_col0, #T_59f5b_row21_col0, #T_59f5b_row22_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_59f5b_row20_col1, #T_59f5b_row22_col1, #T_59f5b_row51_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_59f5b_row21_col1 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_59f5b_row23_col0, #T_59f5b_row24_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_59f5b_row23_col1, #T_59f5b_row30_col1, #T_59f5b_row60_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_59f5b_row24_col1, #T_59f5b_row37_col1, #T_59f5b_row42_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_59f5b_row25_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T
T_59f5b_row182_col1, #T_59f5b_row183_col1, #T_59f5b_row184_col1, #T_59f5b_row185_col1, #T_59f5b_row186_col1, #T_59f5b_row187_col1, #T_59f5b_row188_col1, #T_59f5b_row189_col1, #T_59f5b_row190_col1, #T_59f5b_row191_col1, #T_59f5b_row192_col1, #T_59f5b_row193_col1, #T_59f5b_row194_col1, #T_59f5b_row195_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_59f5b_row29_col1, #T_59f5b_row31_col1, #T_59f5b_row40_col1, #T_59f5b_row44_col1, #T_59f5b_row70_col1, #T_59f5b_row72_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_59f5b_row32_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_59f5b_row33_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_59f5b_row34_col0, #T_59f5b_row35_col0, #T_59f5b_row36_col0, #T_59f5b_row37_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_59f5b_row34_col1, #T_59f5b_row39_col1, #T_59f5b_row46_col1, #T_59f5b_row50_col1, #T_59f5b_row52_col1, #T_59f5b_row79_col1, #T_59f5b_row81_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_59f5b_row35_col1, #T_59f5b_row38_col1, #T_59f5b_row47_col1, #T_59f5b_row48_col1, #T_59f5b_row59_col1, #T_59f5b_row65_col1, #T_59f5b_row84_col1 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_59f5b_row38_col0, #T_59f5b_row39_col0, #T_59f5b_row40_col0, #T_59f5b_row41_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_59f5b_row41_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_59f5b_row42_col0, #T_59f5b_row43_col0, #T_59f5b_row44_col0, #T_59f5b_row45_col0, #T_59f5b_row46_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_59f5b_row43_col1, #T_59f5b_row45_col1, #T_59f5b_row57_col1, #T_59f5b_row58_col1, #T_59f5b_row68_col1, #T_59f5b_row69_col1, #T_59f5b_row71_col1, #T_59f5b_row74_col1, #T_59f5b_row75_col1, #T_59f5b_row80_col1, #T_59f5b_row85_col1, #T_59f5b_row87_col1, #T_59f5b_row88_col1, #T_59f5b_row91_col1, #T_59f5b_row98_col1, #T_59f5b_row99_col1, #T_59f5b_row105_col1, #T_59f5b_row107_col1, #T_59f5b_row112_col1, #T_59f5b_row114_col1, #T_59f5b_row133_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_59f5b_row47_col0, #T_59f5b_row48_col0, #T_59

# %%
px.bar(
    sorted_combined_df.head(10),
    x = "Country",
    y = "Confirmed",
    title= "Top 10 worst affected Countries", # the axis names
    color_discrete_sequence=["Orange"], 
    height=500,
    width=800
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4916/917745883.py in <module>
# ----> 1 px.bar(
#       2     sorted_combined_df.head(10),
#       3     x = "Country",
#       4     y = "Confirmed",
#       5     title= "Top 10 worst affected Countries", # the axis names
#
# NameError: name 'px' is not defined

# %%
world_map = folium.Map(location=[11,0], tiles="cartodbpositron", zoom_start=2, max_zoom = 6, min_zoom = 2)

for i in range(0,len(confirmed_df)):
    folium.Circle(
        location=[confirmed_df.iloc[i]['Lat'] if pd.isna(confirmed_df.iloc[i]['Lat']) == False else 0, confirmed_df.iloc[i]['Long'] if pd.isna(confirmed_df.iloc[i]['Long']) == False else 0],
        fill=True,
        radius=int((np.log2(confirmed_df.iloc[i, -5]+1))*6000),
        color='orange',
        fill_color='#ff8533',
        tooltip = "<div style='margin: 0; background-color: black; color: white;'>"+
                    "<h4 style='text-align:center;font-weight: bold'>"+confirmed_df.index[i] + "</h4>"
                    "<hr style='margin:10px;color: white;'>"+
                    "<ul style='color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px'>"+
                        "<li>Confirmed: "+str(confirmed_df.iloc[i,-5])+"</li>"+
                        "<li>Deaths:   "+str(deaths_df.iloc[i,-8])+"</li>"+
                        "<li>Death Rate: "+ str(np.round(deaths_df.iloc[i,-8]/(confirmed_df.iloc[i,-5]+1.00001)*100,2))+ "</li>"+
                    "</ul></div>",
        ).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_400850d4e1ab4a6a81328efd6c1845d6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_400850d4e1ab4a6a81328efd6c1845d6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_400850d4e1ab4a6a81328efd6c1845d6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_400850d4e1ab4a6a81328efd6c1845d6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B11.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...
